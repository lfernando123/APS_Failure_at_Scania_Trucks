# %%
import pandas as pd
import numpy as np

# Target encoding
df["class"] = df["class"].map({"neg": 0, "pos": 1})

X = df.drop("class", axis=1)
y = df["class"]

# Replace missing values
X = X.fillna(X.median())
